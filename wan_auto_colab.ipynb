# %% [markdown]
# # Wan 2.1 Auto Video GeneratorExecute todas as celulas em sequencia.

# %%
# Automatic setupimport subprocess, time, os%cd /content!git clone -b v0.3.0 --depth 1 https://github.com/comfyanonymous/ComfyUI.git%cd ComfyUI!pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# Install Wan nodes%cd /content/ComfyUI/custom_nodes!git clone https://github.com/kijai/ComfyUI-Wan.git

# %%
# Download models%cd /content/ComfyUI!mkdir -p models/unet models/vae models/clip!wget -q https://huggingface.co/Comfy-Org/Wan_2.1_T2V_1_3B-BP/resolve/main/split_files/diffusion_models/wan2.1_t2v_1.3B_bf16.safetensors -O models/unet/wan2.1_t2v_1.3B_bf16.safetensors!wget -q https://huggingface.co/Comfy-Org/Wan_2.1_T2V_1_3B-BP/resolve/main/split_files/vae/wan_2.1_vae.safetensors -O models/vae/wan_2.1_vae.safetensors!wget -q https://huggingface.co/Comfy-Org/Wan_2.1_T2V_1_3B-BP/resolve/main/split_files/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors -O models/clip/umt5_xxl_fp8_e4m3fn_scaled.safetensors

# %%
# Start ComfyUI%cd /content/ComfyUI!pkill -f main.py 2>/dev/null || trueimport subprocessproc = subprocess.Popen(['python', 'main.py', '--listen', '0.0.0.0', '--port', '8188'])time.sleep(15)print('ComfyUI running at /proxy/8188')
